# %% [markdown]
# Data Augmentation To Address Overfitting In Flower Classification CNN
# In this notebook we will build a CNN to classify flower images. We will also see how our model overfits and how overfitting can be addressed using data augmentation. Data augmentation is a process of generating new training samples from current training dataset using transformations such as zoom, rotations, change in contrast etc
#
# Credits: I used tensorflow offical tutorial: https://www.tensorflow.org/tutorials/images/classification as a reference and made bunch of changes to make it simpler
#
# In below image, 4 new training samples are generated from original sample using different transformations

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# We will download flowers dataset from google website and store it locally. In below call it downloads the zip file (.tgz) in cache_dir which is . meaning the current folder

# %% [markdown]
# **Load flowers dataset**

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# untar true will unzip it
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 1s 0us/step
# 228827136/228813984 [==============================] - 1s 0us/step

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
type(data_dir)
# Out:
# str

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/6036837996_7fbdcdb3c5_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5402157745_a384f0583d_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/2122401867_cd86c5f114_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14001990976_bd2da42dbc.jpg'),
#  PosixPath('datasets/flower_photos/roses/909277823_e6fb8cb5c8_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/6036837996_7fbdcdb3c5_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5402157745_a384f0583d_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/2122401867_cd86c5f114_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14001990976_bd2da42dbc.jpg'),
#  PosixPath('datasets/flower_photos/roses/909277823_e6fb8cb5c8_n.jpg')]

# %%
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x272 at 0x7FCECE1A4C50>

# %%
PIL.Image.open(str(roses[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x7FCECD679590>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=145x240 at 0x7FCECD6EACD0>

# %% [markdown]
# **Read flowers images from disk into numpy array using opencv**

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/6036837996_7fbdcdb3c5_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5402157745_a384f0583d_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/2122401867_cd86c5f114_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14001990976_bd2da42dbc.jpg'),
#  PosixPath('datasets/flower_photos/roses/909277823_e6fb8cb5c8_n.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets/flower_photos/roses/6036837996_7fbdcdb3c5_n.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (272, 320, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# **Train test split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# **Preprocessing: scale images**

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %% [markdown]
# **Build convolutional neural network and train it**

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 14s 23ms/step - loss: 1.3451 - accuracy: 0.4440
# Epoch 2/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.9854 - accuracy: 0.6192
# Epoch 3/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.7973 - accuracy: 0.6926
# Epoch 4/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.6210 - accuracy: 0.7751
# Epoch 5/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.4137 - accuracy: 0.8488
# Epoch 6/30
# 86/86 [==============================] - 2s 23ms/step - loss: 0.2691 - accuracy: 0.9099
# Epoch 7/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.1463 - accuracy: 0.9528
# Epoch 8/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0801 - accuracy: 0.9789
# Epoch 9/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0386 - accuracy: 0.9924
# Epoch 10/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0239 - accuracy: 0.9949
# Epoch 11/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0189 - accuracy: 0.9960
# Epoch 12/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0231 - accuracy: 0.9935
# Epoch 13/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0481 - accuracy: 0.9840
# Epoch 14/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0284 - accuracy: 0.9931
# Epoch 15/30
# 86/86 [==============================] - 2s 23ms/step - loss: 0.0347 - accuracy: 0.9909
# Epoch 16/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0165 - accuracy: 0.9975
# Epoch 17/30
# 86/86 [==============================] - 2s 23ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 18/30
# 86/86 [==============================] - 2s 22ms/step - loss: 6.7789e-04 - accuracy: 1.0000
# Epoch 19/30
# 86/86 [==============================] - 2s 22ms/step - loss: 4.4643e-04 - accuracy: 1.0000
# Epoch 20/30
# 86/86 [==============================] - 2s 23ms/step - loss: 3.4377e-04 - accuracy: 1.0000
# Epoch 21/30
# 86/86 [==============================] - 2s 23ms/step - loss: 2.7329e-04 - accuracy: 1.0000
# Epoch 22/30
# 86/86 [==============================] - 2s 23ms/step - loss: 2.2413e-04 - accuracy: 1.0000
# Epoch 23/30
# 86/86 [==============================] - 2s 23ms/step - loss: 1.8947e-04 - accuracy: 1.0000
# Epoch 24/30
# 86/86 [==============================] - 2s 22ms/step - loss: 1.6198e-04 - accuracy: 1.0000
# Epoch 25/30
# 86/86 [==============================] - 2s 22ms/step - loss: 1.4168e-04 - accuracy: 1.0000
# Epoch 26/30
# 86/86 [==============================] - 2s 23ms/step - loss: 1.2364e-04 - accuracy: 1.0000
# Epoch 27/30
# 86/86 [==============================] - 2s 23ms/step - loss: 1.1026e-04 - accuracy: 1.0000
# Epoch 28/30
# 86/86 [==============================] - 2s 23ms/step - loss: 9.8212e-05 - accuracy: 1.0000
# Epoch 29/30
# 86/86 [==============================] - 2s 23ms/step - loss: 8.8649e-05 - accuracy: 1.0000
# Epoch 30/30
# 86/86 [==============================] - 2s 22ms/step - loss: 8.0061e-05 - accuracy: 1.0000

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 1s 18ms/step - loss: 2.9092 - accuracy: 0.6612
# [2.909181594848633, 0.6612200140953064]

# %% [markdown]
# **Here we see that while train accuracy is very high (99%), the test accuracy is significantly low (66.99%) indicating overfitting. Let's make some predictions before we use data augmentation to address overfitting.**

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([[ -3.147246  ,  15.803073  ,  21.544394  ,  -9.5148535 ,
#          -4.2634034 ],
#        [  8.086041  ,   7.87531   ,  16.664856  ,  -8.321692  ,
#          -6.5487347 ],
#        [ 15.762403  ,   7.1073065 ,  26.5197    , -22.34712   ,
#         -13.839909  ],
#        ...,
#        [  6.5579753 , -12.993943  ,  -2.8624866 ,  28.424267  ,
#          10.946144  ],
#        [ 13.856703  ,  10.822339  ,  -1.8554623 , -25.956188  ,
#          16.435265  ],
#        [ -0.9856673 , -15.075271  ,   0.34226114,  25.066496  ,
#           7.05891   ]], dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])

# %%
np.argmax(score)
# Out:
# 2

# %%
y_test[3]
# Out:
# 4

# %%
img_height = 180
img_width = 180

# %% [markdown]
# **Improve Test Accuracy Using Data Augmentation**

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Original Image

# %%
plt.axis('off')
plt.imshow(X[0])

# %% [markdown]
# **Newly generated training sample using data augmentation.**

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))

# %% [markdown]
# **Train the model using data augmentation and a drop out layer.**

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 3s 26ms/step - loss: 1.3230 - accuracy: 0.4095
# Epoch 2/30
# 86/86 [==============================] - 2s 25ms/step - loss: 1.0815 - accuracy: 0.5709
# Epoch 3/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.9732 - accuracy: 0.6137
# Epoch 4/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.9262 - accuracy: 0.6297
# Epoch 5/30
# 86/86 [==============================] - 2s 29ms/step - loss: 0.8534 - accuracy: 0.6650
# Epoch 6/30
# 86/86 [==============================] - 2s 27ms/step - loss: 0.8139 - accuracy: 0.6777
# Epoch 7/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.7758 - accuracy: 0.6897
# Epoch 8/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.7462 - accuracy: 0.7155
# Epoch 9/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.6994 - accuracy: 0.7326
# Epoch 10/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.6811 - accuracy: 0.7391
# Epoch 11/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.6551 - accuracy: 0.7431
# Epoch 12/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.6458 - accuracy: 0.7420
# Epoch 13/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.6483 - accuracy: 0.7496
# Epoch 14/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.5901 - accuracy: 0.7707
# Epoch 15/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.5601 - accuracy: 0.7827
# Epoch 16/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.5598 - accuracy: 0.7892
# Epoch 17/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.5276 - accuracy: 0.7932
# Epoch 18/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.5108 - accuracy: 0.8034
# Epoch 19/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4787 - accuracy: 0.8129
# Epoch 20/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4518 - accuracy: 0.8252
# Epoch 21/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4601 - accuracy: 0.8238
# Epoch 22/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4391 - accuracy: 0.8401
# Epoch 23/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4093 - accuracy: 0.8550
# Epoch 24/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.4248 - accuracy: 0.8358
# Epoch 25/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3944 - accuracy: 0.8554
# Epoch 26/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3876 - accuracy: 0.8547
# Epoch 27/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3756 - accuracy: 0.8623
# Epoch 28/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3522 - accuracy: 0.8656
# Epoch 29/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3505 - accuracy: 0.8699
# Epoch 30/30
# 86/86 [==============================] - 2s 25ms/step - loss: 0.3212 - accuracy: 0.8888

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 1s 15ms/step - loss: 0.9058 - accuracy: 0.7331
# [0.9057979583740234, 0.7331154942512512]

# %% [markdown]
# # **You can see that by using data augmentation and drop out layer the accuracy of test set predictions is increased to 73.74%**
