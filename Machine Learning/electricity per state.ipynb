# %%
import pandas as pd

# %%
P = pd.read_csv('Peak-Oct18.csv')
P
# Out:
#    State /System /Region  October 2018-Peak Demand-( MW )  \
# 0             Chandigarh                            217.0
# 1                  Delhi                           4713.0
# 2                Haryana                           7948.0
# 3       Himachal Pradesh                           1520.0
# 4        Jammu & Kashmir                           2856.0
# 5                 Punjab                           7990.0
# 6              Rajasthan                          11450.0
# 7          Uttar Pradesh                          17433.7
# 8            Uttarakhand                           1943.0
# 9        Northern Region                          50659.0
# 10           Chattisgarh                           4416.2
# 11               Gujarat                          16624.3
# 12        Madhya Pradesh                          11535.1
# 13           Maharashtra                          23864.0
# 14          Daman & Diu                             341.6
# ...

# %%
P.isnull().sum()
# Out:
# State /System /Region                                   0
# October 2018-Peak Demand-( MW )                         0
# October 2018-Peak Met-( MW )                            0
# October 2018-Surplus / Deficit (-)-( MW )               0
# October 2018-Surplus / Deficit (-)-( % )                0
# April 2018-October 2018-Peak Demand-( MW )              0
# April 2018-October 2018-Peak Met-( MW )                 0
# April 2018-October 2018-Surplus / Deficit (-)-( MW )    0
# April 2018-October 2018-Surplus / Deficit (-)-( % )     0
# dtype: int64

# %%
P.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 9 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   State /System /Region                                 43 non-null     object
#  1   October 2018-Peak Demand-( MW )                       43 non-null     float64
#  2   October 2018-Peak Met-( MW )                          43 non-null     float64
#  3   October 2018-Surplus / Deficit (-)-( MW )             43 non-null     float64
#  4   October 2018-Surplus / Deficit (-)-( % )              43 non-null     float64
#  5   April 2018-October 2018-Peak Demand-( MW )            43 non-null     float64
#  6   April 2018-October 2018-Peak Met-( MW )               43 non-null     float64
#  7   April 2018-October 2018-Surplus / Deficit (-)-( MW )  43 non-null     float64
# ...
